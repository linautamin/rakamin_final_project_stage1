# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import rcParams

##rcParams['figure.figsize']=(10,7)
##rcParams['lines.linewidth']=2.5
##rcParams['xtick.labelsize']='x-large'
##rcParams['ytick.labelsize']='x-large'

# %%
df = pd.read_csv(r'D:\Rakamin-Lina\Rakamin\final project\dataset\Train.csv')
df
# Out:
#           ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# 0          1               D           Flight                    4
# 1          2               F           Flight                    4
# 2          3               A           Flight                    2
# 3          4               B           Flight                    3
# 4          5               C           Flight                    2
# ...      ...             ...              ...                  ...
# 10994  10995               A             Ship                    4
# 10995  10996               B             Ship                    4
# 10996  10997               C             Ship                    5
# 10997  10998               F             Ship                    5
# 10998  10999               D             Ship                    2
#
#        Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 0                    2                  177                3
# ...

# %%
numerical = ['ID', 'Customer_care_calls', 'Customer_rating', 'Cost_of_the_Product', 'Prior_purchases','Discount_offered', 'Weight_in_gms', 'Reached.on.Time_Y.N']
categorical = ['Warehouse_block', 'Mode_of_Shipment', 'Product_importance','Gender']

# %%
df[numerical].describe()
# Out:
#                 ID  Customer_care_calls  Customer_rating  Cost_of_the_Product  \
# count  10999.00000         10999.000000     10999.000000         10999.000000
# mean    5500.00000             4.054459         2.990545           210.196836
# std     3175.28214             1.141490         1.413603            48.063272
# min        1.00000             2.000000         1.000000            96.000000
# 25%     2750.50000             3.000000         2.000000           169.000000
# 50%     5500.00000             4.000000         3.000000           214.000000
# 75%     8249.50000             5.000000         4.000000           251.000000
# max    10999.00000             7.000000         5.000000           310.000000
#
#        Prior_purchases  Discount_offered  Weight_in_gms  Reached.on.Time_Y.N
# count     10999.000000      10999.000000   10999.000000         10999.000000
# mean          3.567597         13.373216    3634.016729             0.596691
# ...

# %%
df[categorical].describe()
# Out:
#        Warehouse_block Mode_of_Shipment Product_importance Gender
# count            10999            10999              10999  10999
# unique               5                3                  3      2
# top                  F             Ship                low      F
# freq              3666             7462               5297   5545

# %%
df["Mode_of_Shipment"].value_counts()
# Out:
# Ship      7462
# Flight    1777
# Road      1760
# Name: Mode_of_Shipment, dtype: int64

# %%
df["Discount_offered"].value_counts()
# Out:
# 10    860
# 2     858
# 6     849
# 9     845
# 3     840
#      ...
# 65     36
# 26     36
# 42     35
# 25     34
# 30     34
# Name: Discount_offered, Length: 65, dtype: int64

# %%
df["Discount_offered"].unique()
# Out:
# array([44, 59, 48, 10, 46, 12,  3, 11, 29, 32,  1, 43, 45,  6, 36, 18, 38,
#        51,  2, 28, 24, 31, 61, 22,  4, 62, 16, 56, 15,  9, 40, 37, 41, 17,
#        64, 52, 49, 39, 14, 33, 21, 13, 23, 26, 57,  7, 35,  8,  5, 53, 55,
#        47, 65, 25, 50, 60, 20, 19, 63, 58, 34, 54, 27, 42, 30],
#       dtype=int64)

# %%
#Univariate Analysis-boxplot
features = numerical
plt.figure(figsize=(12, 5))
for i in range(0, len(features)):
    plt.subplot(1, len(features), i+1)
    sns.boxplot(y=df[features[i]], color='green', orient='v')
    plt.tight_layout()

# %%
plt.figure(figsize=(12, 5))
for i in range(0, len(features)):
    plt.subplot(1, len(features), i+1)
    sns.distplot(df[features[i]], color='gray')
    plt.tight_layout()
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\LENOVO\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
plt.figure(figsize=(12, 5))
for i in range(0, len(features)):
    plt.subplot(1, len(features), i+1)
    sns.violinplot(y=df[features[i]], color='gray', orient='v')
    plt.tight_layout()

# %%
#Univariate Analysis-boxplot
features = categorical
plt.figure(figsize=(12, 5))
for i in range(0, len(features)):
    plt.subplot(1, len(features), i+1)
    sns.countplot(x=df[features[i]], color='green')
    plt.tight_layout()

# %%
#multivariare analysis
sns.heatmap(df.corr(), cmap='Blues', annot=True, fmt='.2f')
# Out:
# <AxesSubplot:>

# %%
#PairPlot
sns.pairplot(df, diag_kind='kde')

# %%
#PairPlot
sns.pairplot(df, diag_kind='kde', hue='Reached.on.Time_Y.N')

# %%
sns.catplot(data=df, x='Mode_of_Shipment', y='Customer_rating', hue='Reached.on.Time_Y.N')

# %%
sns.catplot(data=df, x='Product_importance', y='Customer_rating', hue='Reached.on.Time_Y.N')

# %%
features = numerical
fig = plt.figure(figsize=(15, 15))
for i in range(0, len(numerical)):
    ax = fig.add_subplot(3,3,i+1)
    sns.stripplot(ax=ax, data=df, x='Mode_of_Shipment', y=numerical[i])
    plt.tight_layout()

# %%
features = numerical
fig = plt.figure(figsize=(15, 15))
for i in range(0, len(numerical)):
    ax = fig.add_subplot(3,3,i+1)
    sns.stripplot(ax=ax, data=df, x='Product_importance', y=numerical[i])
    plt.tight_layout()

# %%
features = numerical
fig = plt.figure(figsize=(15, 15))
for i in range(0, len(numerical)):
    ax = fig.add_subplot(3,3,i+1)
    sns.stripplot(ax=ax, data=df, x='Warehouse_block', y=numerical[i])
    plt.tight_layout()

# %%
features = numerical
fig = plt.figure(figsize=(15, 15))
for i in range(0, len(numerical)):
    ax = fig.add_subplot(3,3,i+1)
    sns.stripplot(ax=ax, data=df, x='Gender', y=numerical[i])
    plt.tight_layout()

# %%
##Business Insight
df["Reached.on.Time_Y.N"].value_counts()
# Out:
# 1    6563
# 0    4436
# Name: Reached.on.Time_Y.N, dtype: int64

# %%
#Univariate Analysis-boxplot
features = categorical
plt.figure(figsize=(12, 5))
for i in range(0, len(features)):
    plt.subplot(1, len(features), i+1)
    sns.countplot(x=df[features[i]], color='green')
    plt.tight_layout()
